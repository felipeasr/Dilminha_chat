# %%
pip install python-aiml

# %%
import aiml

# %%
kernel = aiml.Kernel()
kernel.learn("std-startup.xml")
kernel.respond("load aiml b")
# Press CTRL-C to break this loop
while True:
    print(kernel.respond(input("Digite a sua mensgem ")))
# Out:
# Loading std-startup.xml...done (0.00 seconds)
# Loading entretenimento.aiml...done (0.00 seconds)
# Loading sistema.aiml...done (0.00 seconds)
# Loading REFERENCIA.aiml...done (0.00 seconds)
# Digite a sua mensgem oi
# OI, tudo bem ?
# Digite a sua mensgem tudo
# Que bom
# Digite a sua mensgem tudo mal
# Desculpe, eu não entendi...
# Digite a sua mensgem to mal
# ai que pena, dias melhores viram
# Digite a sua mensgem QUAL ESTRUTURA DE UM SISTEMA ESPECIALISTA
# A estrutura básica para um sistema especialista é constituída por três elementos fundamentais: base de conhecimento, motor de inferência e interface com o usuário
# Digite a sua mensgem O QUE É INTERFACE USUÁRIO
# alguns SEs conseguem trabalhar com incerteza ou com informação incompleta;
# Digite a sua mensgem QUAIS AS VANTAGENS DE UTILIZAR SE
# ...
